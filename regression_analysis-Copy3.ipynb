# %% [markdown]
# ### Linear Regression Analysis of ADR
# Using the transformed dataset, I divided the data into three based on the year i.e 2015, 2016 or 2017 dataset then performed the regression analysis on each dataset.

# %%
import pandas as pd
import numpy as np
import calendar
from datetime import datetime
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
hotel_data1 = pd.read_csv('hotel_data1.csv')
hotel_data1.head()
# Out:
#    hotel arrival_date  overnight  adults  children  babies  meal  \
# 0      0   2015-07-01          0       2         0       0     1
# 1      0   2015-07-01          0       2         0       0     1
# 2      0   2015-07-01          1       1         0       0     1
# 3      0   2015-07-01          1       1         0       0     1
# 4      0   2015-07-01          1       2         0       0     1
#
#    reserved_room  booking_changes  deposit_type  agent  company   adr  \
# 0              1                3             0      0        0   0.0
# 1              1                4             0      0        0   0.0
# 2              0                0             0      0        0  75.0
# 3              1                0             0      1        0  75.0
# 4              1                0             0      1        0  98.0
#
#    required_car_parking_spaces  total_of_special_requests reservation_status  \
# 0                            0                          0          Check-Out
# 1                            0                          0          Check-Out
# 2                            0                          0          Check-Out
# 3                            0                          0          Check-Out
# 4                            0                          1          Check-Out
#
#   reservation_status_date  length_of_stay
# 0              2015-07-01               0
# 1              2015-07-01               0
# 2              2015-07-02               1
# 3              2015-07-02               1
# 4              2015-07-03               2

# %%
hotel_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75166 entries, 0 to 75165
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   hotel                        75166 non-null  int64
#  1   arrival_date                 75166 non-null  object
#  2   overnight                    75166 non-null  int64
#  3   adults                       75166 non-null  int64
#  4   children                     75166 non-null  int64
#  5   babies                       75166 non-null  int64
#  6   meal                         75166 non-null  int64
#  7   reserved_room                75166 non-null  int64
#  8   booking_changes              75166 non-null  int64
#  9   deposit_type                 75166 non-null  int64
#  10  agent                        75166 non-null  int64
#  11  company                      75166 non-null  int64
#  12  adr                          75166 non-null  float64
#  13  required_car_parking_spaces  75166 non-null  int64
#  14  total_of_special_requests    75166 non-null  int64
#  15  reservation_status           75166 non-null  object
#  16  reservation_status_date      75166 non-null  object
#  17  length_of_stay               75166 non-null  int64
# dtypes: float64(1), int64(14), object(3)
# memory usage: 10.3+ MB

# %%
# convert columns to the right data type
hotel_data1['arrival_date'] = pd.to_datetime(hotel_data1['arrival_date'])
hotel_data1['reservation_status_date'] = pd.to_datetime(hotel_data1['reservation_status_date'])

# %%
# split the data into years
hotel_data1['arrival_date'] = hotel_data1['arrival_date'].dt.year
data_2015 = hotel_data1.query('arrival_date == 2015')
data_2016 = hotel_data1.query('arrival_date == 2016')
data_2017 = hotel_data1.query('arrival_date == 2017')

# %%
# linear correlation of quantitative variables
data_2015.corr()
# Out:
#                                 hotel  arrival_date  overnight    adults  \
# hotel                        1.000000           NaN   0.042790 -0.137026
# arrival_date                      NaN           NaN        NaN       NaN
# overnight                    0.042790           NaN   1.000000  0.018744
# adults                      -0.137026           NaN   0.018744  1.000000
# children                    -0.064888           NaN  -0.005190  0.070431
# babies                      -0.035137           NaN   0.000051  0.033301
# meal                         0.117045           NaN  -0.011093 -0.031044
# reserved_room                0.051116           NaN   0.084418 -0.000768
# booking_changes             -0.049279           NaN  -0.011846 -0.088700
# deposit_type                -0.010457           NaN   0.003239  0.003908
# agent                        0.122277           NaN   0.031146  0.158720
# company                     -0.065809           NaN  -0.013755 -0.262707
# adr                         -0.020905           NaN   0.209064  0.272796
# required_car_parking_spaces -0.266454           NaN   0.025358  0.087110
# total_of_special_requests   -0.128454           NaN  -0.014480  0.204644
# length_of_stay              -0.303576           NaN   0.138171  0.154802
#
#                              children    babies      meal  reserved_room  \
# hotel                       -0.064888 -0.035137  0.117045       0.051116
# arrival_date                      NaN       NaN       NaN            NaN
# overnight                   -0.005190  0.000051 -0.011093       0.084418
# adults                       0.070431  0.033301 -0.031044      -0.000768
# children                     1.000000  0.030258  0.018969       0.027292
# babies                       0.030258  1.000000  0.010153      -0.013616
# meal                         0.018969  0.010153  1.000000      -0.030428
# reserved_room                0.027292 -0.013616 -0.030428       1.000000
# booking_changes              0.065728  0.037564  0.006878      -0.051970
# deposit_type                -0.006730 -0.002964  0.003217       0.002534
# agent                       -0.025751 -0.009869  0.004576       0.051045
# company                     -0.044868 -0.017843  0.030216      -0.053133
# adr                          0.251630  0.033758 -0.055995       0.068868
# required_car_parking_spaces  0.093192  0.030769  0.032073      -0.022749
# total_of_special_requests    0.133130  0.137130  0.070297       0.016443
# length_of_stay               0.027920  0.021012 -0.024862       0.148449
#
#                              booking_changes  deposit_type     agent  \
# hotel                              -0.049279     -0.010457  0.122277
# arrival_date                             NaN           NaN       NaN
# overnight                          -0.011846      0.003239  0.031146
# adults                             -0.088700      0.003908  0.158720
# children                            0.065728     -0.006730 -0.025751
# babies                              0.037564     -0.002964 -0.009869
# meal                                0.006878      0.003217  0.004576
# reserved_room                      -0.051970      0.002534  0.051045
# booking_changes                     1.000000     -0.001115 -0.075057
# deposit_type                       -0.001115      1.000000 -0.035444
# agent                              -0.075057     -0.035444  1.000000
# company                             0.126145      0.062129 -0.529712
# adr                                -0.010096      0.004414  0.063210
# required_car_parking_spaces         0.039807     -0.002127 -0.075058
# total_of_special_requests          -0.009057     -0.021035  0.100278
# length_of_stay                      0.142171     -0.006431  0.156236
#
#                               company       adr  required_car_parking_spaces  \
# hotel                       -0.065809 -0.020905                    -0.266454
# arrival_date                      NaN       NaN                          NaN
# overnight                   -0.013755  0.209064                     0.025358
# adults                      -0.262707  0.272796                     0.087110
# children                    -0.044868  0.251630                     0.093192
# babies                      -0.017843  0.033758                     0.030769
# meal                         0.030216 -0.055995                     0.032073
# reserved_room               -0.053133  0.068868                    -0.022749
# booking_changes              0.126145 -0.010096                     0.039807
# deposit_type                 0.062129  0.004414                    -0.002127
# agent                       -0.529712  0.063210                    -0.075058
# company                      1.000000 -0.204750                    -0.012262
# adr                         -0.204750  1.000000                     0.127885
# required_car_parking_spaces -0.012262  0.127885                     1.000000
# total_of_special_requests   -0.154798  0.195687                     0.105184
# length_of_stay              -0.066770  0.137165                     0.019528
#
#                              total_of_special_requests  length_of_stay
# hotel                                        -0.128454       -0.303576
# arrival_date                                       NaN             NaN
# overnight                                    -0.014480        0.138171
# adults                                        0.204644        0.154802
# children                                      0.133130        0.027920
# babies                                        0.137130        0.021012
# meal                                          0.070297       -0.024862
# reserved_room                                 0.016443        0.148449
# booking_changes                              -0.009057        0.142171
# deposit_type                                 -0.021035       -0.006431
# agent                                         0.100278        0.156236
# company                                      -0.154798       -0.066770
# adr                                           0.195687        0.137165
# required_car_parking_spaces                   0.105184        0.019528
# total_of_special_requests                     1.000000        0.112026
# length_of_stay                                0.112026        1.000000

# %% [markdown]
# `adr` seems to have correlation with `adults`, `children`, `company` and `special requests`

# %%
# define independent and dependent variables. consider independent variables as those with correlation greater or less than 0.15
y = data_2015['adr']
x1 = data_2015[['overnight', 'adults', 'children', 'total_of_special_requests', 'company']]
x = sm.add_constant(x1)

# %%
# model 1 - all quantitative data including binary data
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    adr   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     688.2
# Date:                Tue, 07 Feb 2023   Prob (F-statistic):               0.00
# Time:                        16:34:06   Log-Likelihood:                -70809.
# No. Observations:               13854   AIC:                         1.416e+05
# Df Residuals:                   13848   BIC:                         1.417e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       -35.8430      3.495    -10.256      0.000     -42.693     -28.993
# overnight                    88.5504      3.265     27.124      0.000      82.151      94.950
# adults                       18.5105      0.746     24.817      0.000      17.049      19.973
# children                     28.7805      1.012     28.451      0.000      26.798      30.763
# total_of_special_requests     6.2071      0.445     13.958      0.000       5.335       7.079
# company                     -20.7290      1.338    -15.497      0.000     -23.351     -18.107
# ==============================================================================
# Omnibus:                     1915.411   Durbin-Watson:                   0.767
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4133.805
# Skew:                           0.834   Prob(JB):                         0.00
# Kurtosis:                       5.092   Cond. No.                         32.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The p-values for all the variables are less than 0.05 indicating that the coefficients are significantly different from 0 however, the R-squared value is quite low

# %%
# linear correlation of quantitative variables
data_2016.corr()
# Out:
#                                 hotel  arrival_date  overnight    adults  \
# hotel                        1.000000           NaN   0.036359  0.014487
# arrival_date                      NaN           NaN        NaN       NaN
# overnight                    0.036359           NaN   1.000000  0.047937
# adults                       0.014487           NaN   0.047937  1.000000
# children                     0.010708           NaN   0.007756  0.027660
# babies                      -0.033059           NaN   0.002268  0.028735
# meal                         0.137524           NaN  -0.006103 -0.016639
# reserved_room                0.140331           NaN   0.090382  0.046985
# booking_changes             -0.052161           NaN   0.008178 -0.058083
# deposit_type                -0.076711           NaN   0.007723 -0.020042
# agent                        0.159478           NaN   0.030353  0.246565
# company                     -0.041852           NaN  -0.014864 -0.315620
# adr                          0.210413           NaN   0.217622  0.322929
# required_car_parking_spaces -0.224239           NaN   0.030849  0.033288
# total_of_special_requests    0.104617           NaN   0.028713  0.221732
# length_of_stay              -0.203083           NaN   0.137157  0.151224
#
#                              children    babies      meal  reserved_room  \
# hotel                        0.010708 -0.033059  0.137524       0.140331
# arrival_date                      NaN       NaN       NaN            NaN
# overnight                    0.007756  0.002268 -0.006103       0.090382
# adults                       0.027660  0.028735 -0.016639       0.046985
# children                     1.000000  0.019674  0.015286      -0.008462
# babies                       0.019674  1.000000 -0.011308      -0.005681
# meal                         0.015286 -0.011308  1.000000      -0.026848
# reserved_room               -0.008462 -0.005681 -0.026848       1.000000
# booking_changes              0.034471  0.086312 -0.024402      -0.063061
# deposit_type                -0.015567 -0.006573  0.007860      -0.001762
# agent                        0.051437 -0.009929  0.023292       0.096260
# company                     -0.065169 -0.014124  0.011297      -0.088399
# adr                          0.315210  0.041228  0.016404       0.153259
# required_car_parking_spaces  0.082233  0.030640  0.018936      -0.025904
# total_of_special_requests    0.097235  0.089007  0.069110       0.042590
# length_of_stay               0.010739  0.011219 -0.049140       0.113516
#
#                              booking_changes  deposit_type     agent  \
# hotel                              -0.052161     -0.076711  0.159478
# arrival_date                             NaN           NaN       NaN
# overnight                           0.008178      0.007723  0.030353
# adults                             -0.058083     -0.020042  0.246565
# children                            0.034471     -0.015567  0.051437
# babies                              0.086312     -0.006573 -0.009929
# meal                               -0.024402      0.007860  0.023292
# reserved_room                      -0.063061     -0.001762  0.096260
# booking_changes                     1.000000      0.036770 -0.084839
# deposit_type                        0.036770      1.000000 -0.091853
# agent                              -0.084839     -0.091853  1.000000
# company                             0.076017      0.121825 -0.623881
# adr                                 0.002696     -0.040170  0.158768
# required_car_parking_spaces         0.039855     -0.002405 -0.092081
# total_of_special_requests          -0.024432     -0.060674  0.168465
# length_of_stay                      0.119907     -0.007937  0.168168
#
#                               company       adr  required_car_parking_spaces  \
# hotel                       -0.041852  0.210413                    -0.224239
# arrival_date                      NaN       NaN                          NaN
# overnight                   -0.014864  0.217622                     0.030849
# adults                      -0.315620  0.322929                     0.033288
# children                    -0.065169  0.315210                     0.082233
# babies                      -0.014124  0.041228                     0.030640
# meal                         0.011297  0.016404                     0.018936
# reserved_room               -0.088399  0.153259                    -0.025904
# booking_changes              0.076017  0.002696                     0.039855
# deposit_type                 0.121825 -0.040170                    -0.002405
# agent                       -0.623881  0.158768                    -0.092081
# company                      1.000000 -0.182560                     0.040821
# adr                         -0.182560  1.000000                     0.094638
# required_car_parking_spaces  0.040821  0.094638                     1.000000
# total_of_special_requests   -0.150749  0.204230                     0.023400
# length_of_stay              -0.122056  0.026718                    -0.040056
#
#                              total_of_special_requests  length_of_stay
# hotel                                         0.104617       -0.203083
# arrival_date                                       NaN             NaN
# overnight                                     0.028713        0.137157
# adults                                        0.221732        0.151224
# children                                      0.097235        0.010739
# babies                                        0.089007        0.011219
# meal                                          0.069110       -0.049140
# reserved_room                                 0.042590        0.113516
# booking_changes                              -0.024432        0.119907
# deposit_type                                 -0.060674       -0.007937
# agent                                         0.168465        0.168168
# company                                      -0.150749       -0.122056
# adr                                           0.204230        0.026718
# required_car_parking_spaces                   0.023400       -0.040056
# total_of_special_requests                     1.000000        0.067911
# length_of_stay                                0.067911        1.000000

# %%
# model 2 
y = data_2016['adr']
x2 = data_2016[['hotel', 'overnight', 'adults', 'children', 'babies', 'reserved_room', 'agent',
                    'company','total_of_special_requests']]
x = sm.add_constant(x2)

# %%
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    adr   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     1698.
# Date:                Tue, 07 Feb 2023   Prob (F-statistic):               0.00
# Time:                        16:34:07   Log-Likelihood:            -1.8480e+05
# No. Observations:               36370   AIC:                         3.696e+05
# Df Residuals:                   36360   BIC:                         3.697e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       -53.4387      2.163    -24.702      0.000     -57.679     -49.198
# hotel                        16.8326      0.434     38.762      0.000      15.981      17.684
# overnight                    82.8740      1.984     41.770      0.000      78.985      86.763
# adults                       23.8458      0.425     56.152      0.000      23.013      24.678
# children                     35.0294      0.528     66.390      0.000      33.995      36.064
# babies                       10.5314      1.817      5.795      0.000       6.970      14.093
# reserved_room                11.0403      0.521     21.185      0.000      10.019      12.062
# agent                        -1.6754      0.717     -2.338      0.019      -3.080      -0.271
# company                     -10.0728      1.024     -9.835      0.000     -12.080      -8.065
# total_of_special_requests     4.6829      0.268     17.476      0.000       4.158       5.208
# ==============================================================================
# Omnibus:                     8913.732   Durbin-Watson:                   0.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30706.493
# Skew:                           1.220   Prob(JB):                         0.00
# Kurtosis:                       6.782   Cond. No.                         39.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# In 2016 data, the R-squared value is higher than that of 2015 although this may be caused by the higher number of independent varibales that are correlated with `adr`.

# %%
# linear correlation of quantitative variables
data_2017.corr()
# Out:
#                                 hotel  arrival_date  overnight    adults  \
# hotel                        1.000000           NaN   0.011820  0.032271
# arrival_date                      NaN           NaN        NaN       NaN
# overnight                    0.011820           NaN   1.000000  0.071101
# adults                       0.032271           NaN   0.071101  1.000000
# children                    -0.012983           NaN   0.012701  0.048903
# babies                      -0.042546           NaN   0.006945  0.028420
# meal                         0.151040           NaN   0.025633  0.063298
# reserved_room                0.167948           NaN   0.074197  0.115300
# booking_changes             -0.052114           NaN  -0.011849 -0.080757
# deposit_type                -0.020631           NaN   0.001391  0.005692
# agent                        0.154500           NaN   0.049664  0.282459
# company                     -0.072233           NaN  -0.002503 -0.304863
# adr                          0.136416           NaN   0.153414  0.376207
# required_car_parking_spaces -0.249540           NaN   0.009164  0.022105
# total_of_special_requests    0.027329           NaN   0.035310  0.173223
# length_of_stay              -0.222190           NaN   0.097563  0.146924
#
#                              children    babies      meal  reserved_room  \
# hotel                       -0.012983 -0.042546  0.151040       0.167948
# arrival_date                      NaN       NaN       NaN            NaN
# overnight                    0.012701  0.006945  0.025633       0.074197
# adults                       0.048903  0.028420  0.063298       0.115300
# children                     1.000000  0.033077  0.014482       0.029508
# babies                       0.033077  1.000000 -0.007172      -0.016343
# meal                         0.014482 -0.007172  1.000000       0.078038
# reserved_room                0.029508 -0.016343  0.078038       1.000000
# booking_changes              0.055639  0.101824 -0.031469      -0.059905
# deposit_type                 0.004771 -0.001802  0.002180      -0.005372
# agent                        0.055318  0.010972  0.096354       0.144692
# company                     -0.065874 -0.026770 -0.019097      -0.127164
# adr                          0.349891  0.032768  0.047907       0.181377
# required_car_parking_spaces  0.058180  0.044456  0.008442      -0.058434
# total_of_special_requests    0.066058  0.084183  0.068909       0.044752
# length_of_stay               0.021483  0.027725 -0.043955       0.110250
#
#                              booking_changes  deposit_type     agent  \
# hotel                              -0.052114     -0.020631  0.154500
# arrival_date                             NaN           NaN       NaN
# overnight                          -0.011849      0.001391  0.049664
# adults                             -0.080757      0.005692  0.282459
# children                            0.055639      0.004771  0.055318
# babies                              0.101824     -0.001802  0.010972
# meal                               -0.031469      0.002180  0.096354
# reserved_room                      -0.059905     -0.005372  0.144692
# booking_changes                     1.000000     -0.005068 -0.076488
# deposit_type                       -0.005068      1.000000 -0.044565
# agent                              -0.076488     -0.044565  1.000000
# company                             0.060255      0.059245 -0.650080
# adr                                 0.024699     -0.016404  0.234401
# required_car_parking_spaces         0.049137      0.001375 -0.094202
# total_of_special_requests           0.015763     -0.012929  0.154799
# length_of_stay                      0.098429     -0.018053  0.159378
#
#                               company       adr  required_car_parking_spaces  \
# hotel                       -0.072233  0.136416                    -0.249540
# arrival_date                      NaN       NaN                          NaN
# overnight                   -0.002503  0.153414                     0.009164
# adults                      -0.304863  0.376207                     0.022105
# children                    -0.065874  0.349891                     0.058180
# babies                      -0.026770  0.032768                     0.044456
# meal                        -0.019097  0.047907                     0.008442
# reserved_room               -0.127164  0.181377                    -0.058434
# booking_changes              0.060255  0.024699                     0.049137
# deposit_type                 0.059245 -0.016404                     0.001375
# agent                       -0.650080  0.234401                    -0.094202
# company                      1.000000 -0.227912                     0.051791
# adr                         -0.227912  1.000000                     0.070829
# required_car_parking_spaces  0.051791  0.070829                     1.000000
# total_of_special_requests   -0.143213  0.211398                     0.049556
# length_of_stay              -0.119398  0.038420                    -0.035459
#
#                              total_of_special_requests  length_of_stay
# hotel                                         0.027329       -0.222190
# arrival_date                                       NaN             NaN
# overnight                                     0.035310        0.097563
# adults                                        0.173223        0.146924
# children                                      0.066058        0.021483
# babies                                        0.084183        0.027725
# meal                                          0.068909       -0.043955
# reserved_room                                 0.044752        0.110250
# booking_changes                               0.015763        0.098429
# deposit_type                                 -0.012929       -0.018053
# agent                                         0.154799        0.159378
# company                                      -0.143213       -0.119398
# adr                                           0.211398        0.038420
# required_car_parking_spaces                   0.049556       -0.035459
# total_of_special_requests                     1.000000        0.048895
# length_of_stay                                0.048895        1.000000

# %%
# model 3
y = data_2017['adr']
x2 = data_2017[['overnight', 'adults', 'children', 'reserved_room', 'agent', 'company','total_of_special_requests']]
x = sm.add_constant(x2)

# %%
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    adr   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     2461.
# Date:                Tue, 07 Feb 2023   Prob (F-statistic):               0.00
# Time:                        16:49:48   Log-Likelihood:            -1.3033e+05
# No. Observations:               24942   AIC:                         2.607e+05
# Df Residuals:                   24937   BIC:                         2.607e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                       -50.6827      3.972    -12.761      0.000     -58.467     -42.898
# overnight                    88.5079      3.922     22.564      0.000      80.820      96.196
# adults                       33.9999      0.563     60.340      0.000      32.896      35.104
# children                     41.2310      0.685     60.199      0.000      39.888      42.573
# total_of_special_requests     7.6872      0.326     23.585      0.000       7.048       8.326
# ==============================================================================
# Omnibus:                     2457.412   Durbin-Watson:                   0.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5029.888
# Skew:                           0.641   Prob(JB):                         0.00
# Kurtosis:                       4.788   Cond. No.                         49.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# In 2017 data, the R-squared value is higher indicating that the variation in `adr` is better explained compared to the other years. The adjusted R-squared is lower than the R-squared which means that there are non-significant variables in the model.
